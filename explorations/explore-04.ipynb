# %%
import pandas as pd
import numpy as np
import random
import math
import scipy
from scipy import stats

from sklearn.preprocessing import StandardScaler  # for feature scaling
from sklearn.model_selection import train_test_split  # for train/test split
import matplotlib.pyplot as plt  #For representation
from sklearn.linear_model import LogisticRegression
from sklearn.svm import l1_min_c  # for L1 regluarization path

# Netork modules
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.optim as optim

import copy

# Example code for calculating accuracy, precision, recall, and F1-score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

from statkit.decision import net_benefit

from scipy import integrate

# %% [markdown]
# # Initialize

# %% [markdown]
# Define funtions

# %% [markdown]
# ### Synthetic data

# %%
# Initialise sklearn LR (used for comparison)

logreg = LogisticRegression()

# %%
# Make synthetic data #
#=====================#


def make_synth_data(n_features = 3, n_sample = 1000, true_coefs = [1.,2.,3.], noise = 'none'):
    # initialise
    df = pd.DataFrame()

    # Standardization of variables
    mean_vars = [0 for i in range(n_features)]
    var_vars = [1 for i in range(n_features)]

    # Amount of noise to add to  each variable
    #noise_scale = [i**2 for i in range(n_features)]
    #noise_scale = [0.05*i/(n_features-1)**2 for i in noise_scale]
    if noise == 'none':
        noise_scale = [0 for i in range(n_features)]
    else:
        noise_scale = noise

    # create normal variables
    for n in range(n_features):
        df[n] =  np.random.normal(loc=mean_vars[n], scale=var_vars[n], size=n_sample)

    # create linear combination
    df["x"] = 0
    for n in range(n_features):
        df["x"] +=  true_coefs[n]*df[n]

    # Generate outcome

    df["p"] = df.apply(lambda row: 1./(1. + math.exp(-row["x"])), axis=1)
    df["y"] = df.apply(lambda row: np.random.binomial(1, row["p"] ), axis=1)

    # Add noise to each variable
    df_noisy = df.copy()

    for n in range(n_features):
        df_noisy[n] += np.random.normal(loc=0.0, scale=noise_scale[n], size=n_sample)

    #df = df.drop(["x", "p"], axis=1)
    df_noisy = df_noisy.drop(["x", "p"], axis=1)

    # rename the indpendent variables
    ind_var_rename = dict()
    for ind_var_in in range(n_features) :
        ind_var_rename[ind_var_in] = "x"+f"{ind_var_in}"
    df = df.rename(columns=ind_var_rename)
    df_noisy = df_noisy.rename(columns=ind_var_rename)

    ind_var_names = list(ind_var_rename.values())


    # Split the data
    #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)
    df_train, df_test, df_noisy_train, df_noisy_test = train_test_split(df, df_noisy, test_size=0.2, random_state=1234)

    # Standardize each split

    for indep_var in ind_var_names:
        df_train[indep_var] = stats.zscore(df_train[indep_var]) 
        df_test[indep_var] = stats.zscore(df_test[indep_var]) 

        df_noisy_train[indep_var] = stats.zscore(df_noisy_train[indep_var]) 
        df_noisy_test[indep_var] = stats.zscore(df_noisy_test[indep_var]) 

    # scale data
    #sc = StandardScaler()
    #df_train = sc.fit_transform(df_train)
    #X_test = sc.transform(X_test)

    return df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs

# %%
def mean_net_benefit(y_true, y_pred, n_thresh):
    thresh = np.linspace(0.0, 1.0, num=n_thresh)

    nb = net_benefit(y_true, y_pred , thresholds=thresh)

    mnb = integrate.simpson(nb[1], x=nb[0])

    return({
        'mnb': mnb,
        'benefit': nb[1],
        'thresholds': nb[0] 
    })

# %% [markdown]
# ### Torch LR functions

# %%
#==================#
#    Load Data     #
#==================#


class SynthDataset(Dataset):


    def __init__(self, df):

        # The target is binary
        self.target = ["y"]   #["flow", "handling", "respect"]
        self.features = ind_var_names
        self.data_frame = df.loc[:, self.target+self.features]
        self.n_features = len(self.features)

        # Save target and predictors
        self.x = self.data_frame[self.features]
        self.y = self.data_frame.loc[:,"y"]


    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        # Convert idx from tensor to list due to pandas bug (that arises when using pytorch's random_split)
        if isinstance(idx, torch.Tensor):
            idx = idx.tolist()

        return  [self.x.iloc[idx].values.astype(float),  self.y.iloc[idx].astype(float)] #,  self.handling.iloc[idx].astype(float),  self.respect.iloc[idx].astype(float)]

# %%
# Create model
# f = wx + b, sigmoid at the end

class TorchLogisticRegression(nn.Module):

    def __init__(self, n_input_features):
        super(TorchLogisticRegression, self).__init__()
        self.linear = nn.Linear(n_input_features, 1)

    def forward(self, x):
        #y_predicted = torch.sigmoid(self.linear(x))
        y_predicted = self.linear(x)
        return y_predicted

# %%
#
# Maximum net benefit loss
#

#class mnbLoss(nn.Module):
#    def __init__(self):
#        super(mnbLoss, self).__init__()
#        #self.weight = weight
#
#    def forward(self, input, target):
#        # Compute the loss
#        loss = -torch.sum(target*input+(1-target)*(input*torch.log(1-input)))
#        return loss
    
class mnbLoss(nn.Module):
    def __init__(self):
        super(mnbLoss, self).__init__()
        #self.weight = weight

    def forward(self, input, target):
        # Compute the loss
        #loss = torch.mean(self.weight * (input - target) ** 2)
        #loss = -torch.mean(target*input+(1-target)*(input + torch.log(1-input)))
        #loss = -torch.mean(target*torch.log(input)+(1.-target)*(torch.log(1.-input)))

        #neg_part = torch.clamp(-torch.log(input), min = 0., max = 100.)
        #pos_part = torch.clamp(-torch.log(1.-input), min = 0., max = 100.)

        #loss = target*neg_part+(1.-target)*pos_part 
        #loss = torch.mean(loss)
        #loss = torch.clamp(loss, min = 0., max = 100.)

        #epsilon = 1e-12
        #pred = torch.clamp(pred, epsilon, 1.0 - epsilon)
        #loss = - (target * torch.log(pred) + (1 - target) * torch.log(1 - pred))
        #epsilon = 1e-12
        #pred = torch.clamp(input, epsilon, 1.0 - epsilon)
        #loss = - (target * torch.log(pred) + (1 - target) * torch.log(1 - pred))
        #loss = torch.mean(loss)
        #loss = -torch.mean(target*torch.log(input)+(1.-target)*(torch.log(1.-input)))
        #loss = torch.cat((loss.unsqueeze(0), torch.tensor([100.0]) ))
        #loss = torch.min(loss)
        A = torch.log(1.0 + torch.exp(-input))
        loss = target*A+(1.-target)*(input+A)
        loss = torch.mean(loss)

        return loss

# %%
t = mnbLoss()
t2 = nn.BCELoss()

tg = torch.tensor([1.0, 0.0])
pr = torch.tensor([0.2 , 0.4])

print(t(pr, tg), t2(pr, tg))

#print(tg*torch.log(pr),  (1-tg)*(torch.log(1. - pr)))
#1.-tg
#torch.log(1. - pr)

#torch.cat((tg, pr))

#test_run['loss'][696]

#train_dataset_orig = SynthDataset(df_train)
#    train_x = torch.from_numpy(train_dataset_orig.x.to_numpy().astype(np.float32) )
#train_y = torch.from_numpy(train_dataset_orig.y.to_numpy().astype(np.float32))


#pr = test_run['out'][631].squeeze()

#(train_y.shape, pr.squeeze().shape)

#print(t(pr, train_y) ,t2(pr, train_y))
##df_train['y']
# Out:
# tensor(0.7556) tensor(1.0601)

# %%
#=======================#
#     LR Training       #
#=======================#


def lr_train(train_in, n_epochs=100, learn_rate = 0.01, save_name_mod = "", loss_fun = 'log'):

    # Load dataset
    train_dataset_orig = SynthDataset(train_in)

    train_x = torch.from_numpy(train_dataset_orig.x.to_numpy().astype(np.float32) )
    train_y = torch.from_numpy(train_dataset_orig.y.to_numpy().astype(np.float32))

    train_y = train_y.view(train_y.shape[0], 1)

    # Define the model
    net=TorchLogisticRegression(train_dataset_orig.n_features)
    
    # Loss function

    if loss_fun == 'log':
        #criterion = nn.BCELoss()
        criterion = nn.BCEWithLogitsLoss()
        #criterion = mnbLoss()
    elif loss_fun == 'mnb':
        criterion = mnbLoss()

    # Optimizer
    optimizer = torch.optim.SGD(net.parameters(), lr=learn_rate)
    #optimizer = optim.Adam(net.parameters(), lr=learn_rate, weight_decay=w_decay)
    #optimizer = optim.Adam(net.parameters(),  lr = 0.001, weight_decay = 0.0001 )
    #torch.optim.SGD(model.parameters(), lr=learning_rate)
    #optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    #optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)

    loss_per_epoch = []
    out_per_epoch = []

    for epoch in range(n_epochs):

        y_pred = net(train_x )

        loss=criterion(y_pred, train_y )
        
        loss.backward()

        optimizer.step()
        
        #print("loss = {}".format(loss))
        #for p in net.parameters():    
        #    print('=============\ngradient:{}'.format(p.grad))

        # Zero the parameter gradients
        optimizer.zero_grad()
         
        loss_per_epoch.append(loss.item())
        #out_per_epoch.append(y_pred.detach().clone() )
        #out_per_epoch.append((loss.item()- alt_loss.item() ))
    #return net
    return {"net": net, "loss": loss_per_epoch, "out": out_per_epoch}

# %%
# Fit with torch implementation
#================================#

#test_run = lr_train(df_train, n_epochs=1000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'mnb')
##test_run = reg_lr_train_legacy(df_train, n_epochs=100, learn_rate=  0.1, save_name_mod = "", loss_fun = 'mnb')

#print(test_run['net'].linear.weight, test_run['net'].linear.bias, true_coefs)


## plt.plot(np.arange(len(loss_per_iter)), loss_per_iter, "-", alpha=0.5, label="Loss per epoch")
#plt.plot(np.arange(len(test_run['loss'] )), test_run['loss'], "-", alpha=0.5, label="Loss per epoch")
##plt.plot(np.arange(len(test_run_minibatch['valid_loss_per_batch'])), test_run_minibatch['valid_loss_per_batch'], "-", alpha=0.5, label="Validation Loss per epoch")
##    #plt.plot(np.arange(len(loss_per_iter), step=4) + 3, loss_per_batch, ".-", label="Loss per mini-batch")
#plt.xlabel("Number of epochs")
#plt.ylabel("Loss")
#plt.legend()
#plt.show()

# %%
#===================================#
#     Regularized LR Training       #
#===================================#

#tps://www.geeksforgeeks.org/l1l2-regularization-in-pytorch/

def reg_lr_train_legacy(net, train_in, n_epochs=100, learn_rate = 0.01, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [], lambda_reg = 0.01):

    # Load dataset
    train_dataset_orig = SynthDataset(train_in)

    train_x = torch.from_numpy(train_dataset_orig.x.to_numpy().astype(np.float32) )
    train_y = torch.from_numpy(train_dataset_orig.y.to_numpy().astype(np.float32))

    train_y = train_y.view(train_y.shape[0], 1)

    # Define the model
    #net=TorchLogisticRegression(train_dataset_orig.n_features)
    
    # Loss function

    if loss_fun == 'log':
        criterion = nn.BCEWithLogitsLoss()
    elif loss_fun == 'mnb':
        criterion = mnbLoss()

    # Optimizer
    optimizer = optim.Adam(net.parameters(),  lr = 1.0)
    #optimizer = optim.ASGD(net.parameters(), lr=0.01)
    #optimizer = optim.LBFGS(net.parameters())
    #optimizer = optim.Rprop(net.parameters(), lr=1.0)

    #optimizer = torch.optim.SGD(net.parameters(), lr=learn_rate)
    #optimizer = torch.optim.SGD(net.parameters(), lr=learn_rate)
    

    #def closure():
    #    optim.lbfgs.zero_grad()
    #    objective = f(x_lbfgs)
    #    objective.backward()
    #    return objective

    #optimizer = torch.optim.LBFGS(net.parameters(), lr=1.0)
    #torch.optim.SGD(model.parameters(), lr=learning_rate)
    #optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
    #optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)



    #t = torch.from_numpy(np.array([[1,2,1]]))
    #
    #s = [p[1] for p in enumerate(model.parameters())][0].abs()

    # A tensor of weights for the weighted L1
    if regularization_type == 'weighted_L1':
        weights = [
            torch.from_numpy(np.array([weights])),
            torch.from_numpy(np.array([1.0])),
        ]

    

    for epoch in range(n_epochs):

        y_pred = net(train_x )

        loss=criterion(y_pred, train_y )

        # add regularization term #
        #-------------------------#

        # Apply L1 regularization
        if regularization_type == 'L1':
            #l1_norm = sum(p.abs().sum() for p in net.parameters() )
            l1_norm = [p.abs().sum() for p in net.parameters()][0] 
            #l1_norm = [p.abs().sum() for p in net.parameters()][0] 
            #l1_norm = torch.mean(p.abs().sum() for p in net.parameters() )

            loss += lambda_reg * l1_norm
            
        # Apply weighted L1 regularization
        elif regularization_type == 'weighted_L1':
            #wl1_norm = sum(torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters()))
            wl1_norm = [torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters())][0]
            loss += lambda_reg * wl1_norm



        loss.backward()

        clipping_value = 1 # arbitrary value of your choosing
        torch.nn.utils.clip_grad_norm(net.parameters(), clipping_value)

        optimizer.step()
        
        # Zero the parameter gradients
        optimizer.zero_grad()

        #if (epoch+1) % 10 == 0:
        #    print(f'epoch: {epoch+1}, loss = {loss.item():.4f}')   
    print("loss : ")     
    print(loss)
    return net

# %%
#===================================#
#     Regularized LR Training       #
#===================================#

#tps://www.geeksforgeeks.org/l1l2-regularization-in-pytorch/

def reg_lr_train(net, train_in, n_epochs=100, learn_rate = 0.01, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [], lambda_reg = 0.01):

    # Load dataset
    train_dataset_orig = SynthDataset(train_in)

    train_x = torch.from_numpy(train_dataset_orig.x.to_numpy().astype(np.float32))
    train_y = torch.from_numpy(train_dataset_orig.y.to_numpy().astype(np.float32))

    train_y = train_y.view(train_y.shape[0], 1)

    # Define the model
    #net=TorchLogisticRegression(train_dataset_orig.n_features)
    
    # Loss function

    if loss_fun == 'log':
        criterion = nn.BCEWithLogitsLoss()
    elif loss_fun == 'mnb':
        criterion = mnbLoss()

    # Optimizer
    def closure():
        
        lbfgs.zero_grad()
        y_pred = net(train_x )
        loss=criterion(y_pred, train_y)

        # add regularization term #
        #-------------------------#

        # Apply L1 regularization
        if regularization_type == 'L1':
            #l1_norm = sum(p.abs().sum() for p in net.parameters() )
            l1_norm = [p.abs().sum() for p in net.parameters()][0] 
            #l1_norm = [p.abs().sum() for p in net.parameters()][0] 
            #l1_norm = torch.mean(p.abs().sum() for p in net.parameters() )

            loss += lambda_reg * l1_norm
            
        # Apply weighted L1 regularization
        elif regularization_type == 'weighted_L1':
            #wl1_norm = sum(torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters()))
            wl1_norm = [torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters())][0]
            loss += lambda_reg * wl1_norm

        loss.backward()
        return loss
        #optimizer.step()
        
        # Zero the parameter gradients
        #optimizer.zero_grad()
    

    #tol=1e-6,
    #max_iter=int(1e6),
    #warm_start=True,
    #intercept_scaling=10000.0,


    lbfgs = optim.LBFGS(net.parameters(),
                    history_size=100, 
                    max_iter=100, 
                    line_search_fn="strong_wolfe")

    # A tensor of weights for the weighted L1
    if regularization_type == 'weighted_L1':
        weights = [
            torch.from_numpy(np.array([weights])),
            torch.from_numpy(np.array([1.0])),
        ]

    for epoch in range(n_epochs):

        lbfgs.step(closure)

    #print("loss : ")     
    #print(loss)
    return net

# %% [markdown]
# ## Minibatch version

# %%
def validate(loader, model, criterion, device):                       
    #correct = 0                                               
    #total = 0                                                 
    running_loss = 0.0                                        
    model.eval()
      
    with torch.no_grad():                                     
        for i, data in enumerate(loader):                     
            inputs, labels = data                             
            inputs = inputs.to(device)                        
            labels = labels.to(device)                        
            
            outputs = model(inputs.float()).squeeze()    

            labels_hat=outputs.float()

            #loss = criterion(labels_hat, labels1.squeeze().type(torch.LongTensor)-1)
            loss = criterion(labels_hat.double(), labels.double())

            running_loss = running_loss + loss.item()
         
    return running_loss/(i+1)

# %%
def lr_train_minibatch(train_in, n_epochs=100, batch_size = 30, learn_rate = 0.01, save_name_mod = "", loss_fun = 'log'):
    """Trains the model.
    Args:
        csv_file (str): Absolute path of the dataset used for training.
        n_epochs (int): Number of epochs to train.
    """
    # Load dataset
    train_dataset_orig = SynthDataset(train_in)

    train_size = int(0.8 * len(train_dataset_orig))
    valid_size = len(train_dataset_orig) - train_size
    train_dataset, valid_dataset = random_split(train_dataset_orig, [train_size, valid_size])

    # Dataloaders
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    validloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    # Use gpu if available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Define the model
    net=TorchLogisticRegression(train_dataset_orig.n_features)
    
    # Loss function

    if loss_fun == 'log':
        criterion = nn.BCEWithLogitsLoss()
    elif loss_fun == 'mnb':
        criterion = mnbLoss()

    # Optimizer
  
    optimizer = torch.optim.SGD(net.parameters(), lr=learn_rate)

    # Train the net
    loss_per_iter = []
    loss_per_batch = []

    #valid_loss_per_iter = []
    valid_loss_per_batch = []

    best_loss = np.inf

    for epoch in range(n_epochs):

        running_loss = 0.0
        for i, (inputs, label) in enumerate(trainloader):
            inputs = inputs.to(device)
            label = label.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward + backward + optimize
            outputs = net(inputs.float() ).squeeze()

            label_hat=outputs.float()

            #print("main: inputs = "+str(inputs.shape) + " outputs = "+ str(outputs.shape))
            #print("main: label_hat = "+str(label_hat.shape) + " label = "+ str(label.shape))

            # calculate loss
            #loss=criterion(label_hat, label.squeeze().type(torch.LongTensor)-1)
            loss=criterion(label_hat.double(), label.double() )

            

            #loss = criterion(outputs, labels.float())
            loss.backward()
            optimizer.step()

            # Save loss to plot
            running_loss += loss.item()
            loss_per_iter.append(loss.item())

        loss_per_batch.append(running_loss / (i + 1))
        running_loss = 0.0

        # Evaluate validation loss
        vloss = validate(validloader, net, criterion, device)
        valid_loss_per_batch.append(vloss)

        # If validation loss is lower than lowest then save the model
        #if vloss < best_loss:
        #    save_network(net, "best_model"+save_name_mod)
        #    best_loss = vloss

  
    #print("Root mean squared error")
    #print("Training:", np.sqrt(loss_per_batch[-1]))

    return{"model":net,
           "loss_per_batch": loss_per_batch,
           "valid_loss_per_batch": valid_loss_per_batch}

# %%
def reg_validate(loader, model, criterion, device, regularization_type = 'L1', weights = [], lambda_reg = 0.01):                       
    #correct = 0                                               
    #total = 0                                                 
    running_loss = 0.0                                        
    model.eval()
      
    with torch.no_grad():                                     
        for i, data in enumerate(loader):                     
            inputs, labels = data                             
            inputs = inputs.to(device)                        
            labels = labels.to(device)                        
            
            outputs = model(inputs.float()).squeeze()    

            labels_hat=outputs.float()

            #loss = criterion(labels_hat, labels1.squeeze().type(torch.LongTensor)-1)
            loss = criterion(labels_hat.double(), labels.double())


            # add regularization term #
            #-------------------------#

            # Apply L1 regularization
            if regularization_type == 'L1':
                #l1_norm = sum(p.abs().sum() for p in net.parameters() )
                #l1_norm = [p.abs().sum() for p in net.parameters()][0] 
                l1_norm = [p.abs().sum() for p in model.parameters()][0] 
                #l1_norm = torch.mean(p.abs().sum() for p in net.parameters() )

                loss += lambda_reg * l1_norm
            
            #  Apply weighted L1 regularization
            elif regularization_type == 'weighted_L1':
                #wl1_norm = sum(torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(model.parameters()))
                wl1_norm = [torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(model.parameters())][0]
                loss += lambda_reg * wl1_norm
                

            running_loss = running_loss + loss.item()
         
    return running_loss/(i+1)

# %%
def reg_lr_train_minibatch(train_in, n_epochs=100, batch_size = 30, learn_rate = 0.01, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [], lambda_reg = 0.01):
    """Trains the model.
    Args:
        csv_file (str): Absolute path of the dataset used for training.
        n_epochs (int): Number of epochs to train.
    """
    # Load dataset
    train_dataset_orig = SynthDataset(train_in)

    train_size = int(0.8 * len(train_dataset_orig))
    valid_size = len(train_dataset_orig) - train_size
    train_dataset, valid_dataset = random_split(train_dataset_orig, [train_size, valid_size])

    # Dataloaders
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    validloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

    # Use gpu if available
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Define the model
    net=TorchLogisticRegression(train_dataset_orig.n_features)
    
    # Loss function

    if loss_fun == 'log':
        criterion = nn.BCEWithLogitsLoss()
    elif loss_fun == 'mnb':
        criterion = mnbLoss()

    # Optimizer
  
    optimizer = torch.optim.SGD(net.parameters(), lr=learn_rate)

    # Train the net
    loss_per_iter = []
    loss_per_batch = []

    #valid_loss_per_iter = []
    valid_loss_per_batch = []

    best_loss = np.inf

    for epoch in range(n_epochs):

        running_loss = 0.0
        for i, (inputs, label) in enumerate(trainloader):
            inputs = inputs.to(device)
            label = label.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward + backward + optimize
            outputs = net(inputs.float() ).squeeze()

            label_hat=outputs.float()

            #print("main: inputs = "+str(inputs.shape) + " outputs = "+ str(outputs.shape))
            #print("main: label_hat = "+str(label_hat.shape) + " label = "+ str(label.shape))

            # calculate loss
            #loss=criterion(label_hat, label.squeeze().type(torch.LongTensor)-1)
            loss=criterion(label_hat.double(), label.double() )

            # add regularization term #
            #-------------------------#

            # Apply L1 regularization
            if regularization_type == 'L1':
                #l1_norm = sum(p.abs().sum() for p in net.parameters() )
                #l1_norm = [p.abs().sum() for p in net.parameters()][0] 
                l1_norm = [p.abs().sum() for p in net.parameters()][0] 
                #l1_norm = torch.mean(p.abs().sum() for p in net.parameters() )

                loss += lambda_reg * l1_norm
            
            #  Apply weighted L1 regularization
            elif regularization_type == 'weighted_L1':
                #wl1_norm = sum(torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters()))
                wl1_norm = [torch.mul(weights[p[0]], p[1]).abs().sum() for p in enumerate(net.parameters())][0]
                loss += lambda_reg * wl1_norm

            #loss = criterion(outputs, labels.float())
            loss.backward()
            optimizer.step()

            # Save loss to plot
            running_loss += loss.item()
            loss_per_iter.append(loss.item())

        loss_per_batch.append(running_loss / (i + 1))
        running_loss = 0.0

        # Evaluate validation loss
        vloss = reg_validate(validloader, net, criterion, device, regularization_type = regularization_type, weights = weights, lambda_reg = lambda_reg)
        valid_loss_per_batch.append(vloss)

        # If validation loss is lower than lowest then save the model
        #if vloss < best_loss:
        #    save_network(net, "best_model"+save_name_mod)
        #    best_loss = vloss

  
    #print("Root mean squared error")
    #print("Training:", np.sqrt(loss_per_batch[-1]))

    return{"model":net,
           "loss_per_batch": loss_per_batch,
           "valid_loss_per_batch": valid_loss_per_batch}

# %% [markdown]
# ## Test Torch LR

# %% [markdown]
# ### Agreement of LR parameters

# %%
# Create a dataset
#===================#
n_sample = 100000

#make_synth_data(n_features = 10, n_sample = 100000, true_coefs = [3, 2.5, -2.0, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])
#make_synth_data(n_features = 3, n_sample = 100000, true_coefs = [ 3,2,1 ])

#df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs = \
#    make_synth_data(n_features = 10, n_sample = n_sample, true_coefs = [3, 2.5, -2.0, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])

df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs = \
    make_synth_data(n_features = 3, n_sample = n_sample, true_coefs = [3, 2.5, -2.0]) #, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])

# %%
# Visualize synthetic data set
#================================#

x1 = df_train.loc[df_train.y==0]['x0']
x2 = df_train.loc[df_train.y==1]['x0']

kwargs = dict(alpha=0.5, bins=100)

plt.hist(x1, **kwargs, label='0')
plt.hist(x2, **kwargs, label='1')
plt.show()


#plt.gca().set(title='Frequency Histogram of Diamond Depths', ylabel='Frequency')
#plt.xlim(50,75)
#plt.legend();

# %%
# Fit a logistic regression with sklearn
#==========================================#

logreg.fit(df_train[ind_var_names], df_train["y"])

print(logreg.coef_)
#print(logreg.n_features_in_)
# Out:
# [[ 2.96408332  2.48015023 -1.99672323  1.78999034 -1.50574527  1.21003025
#    0.779673    0.51170584 -0.20886131  0.12532114]]

# %%
# Fit with torch implementation
#================================#

#test_run = lr_train(df_train, n_epochs=1000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')
test_run = lr_train(df_train, n_epochs=20000, learn_rate=  0.001, save_name_mod = "", loss_fun = 'mnb')

test_run.linear.weight, test_run.linear.bias, true_coefs
# Out:
# epoch: 10, loss = -0.1054
# epoch: 20, loss = -0.1058
# epoch: 30, loss = -0.1062
# epoch: 40, loss = -0.1065
# epoch: 50, loss = -0.1069
# epoch: 60, loss = -0.1073
# epoch: 70, loss = -0.1076
# epoch: 80, loss = -0.1080
# epoch: 90, loss = -0.1084
# epoch: 100, loss = -0.1087
# epoch: 110, loss = -0.1091
# epoch: 120, loss = -0.1094
# epoch: 130, loss = -0.1098
# epoch: 19730, loss = -0.2983
# epoch: 19740, loss = -0.2984
# epoch: 19750, loss = -0.2984
# epoch: 19760, loss = -0.2984
# epoch: 19770, loss = -0.2984
# epoch: 19780, loss = -0.2984
# epoch: 19790, loss = -0.2985
# epoch: 19800, loss = -0.2985
# epoch: 19810, loss = -0.2985
# epoch: 19820, loss = -0.2985
# epoch: 19830, loss = -0.2985
# epoch: 19840, loss = -0.2986
# epoch: 19850, loss = -0.2986
# epoch: 19860, loss = -0.2986
# epoch: 19870, loss = -0.2986
# epoch: 19880, loss = -0.2986
# epoch: 19890, loss = -0.2987
# epoch: 19900, loss = -0.2987
# epoch: 19910, loss = -0.2987
# epoch: 19920, loss = -0.2987
# epoch: 19930, loss = -0.2987
# epoch: 19940, loss = -0.2988
# epoch: 19950, loss = -0.2988
# epoch: 19960, loss = -0.2988
# epoch: 19970, loss = -0.2988
# epoch: 19980, loss = -0.2988
# epoch: 19990, loss = -0.2989
# epoch: 20000, loss = -0.2989
# (Parameter containing:
#  tensor([[ 1.3261,  1.0198, -0.8215]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.1264], requires_grad=True),
#  [3, 2.5, -2.0])

# %%
# Fit with torch implementation
#================================#

test_run = lr_train(df_train, n_epochs=6500, learn_rate=  1.0, save_name_mod = "", loss_fun = 'mnb')
#test_run = reg_lr_train_legacy(df_train, n_epochs=100, learn_rate=  0.1, save_name_mod = "", loss_fun = 'mnb')

print(test_run['net'].linear.weight, test_run['net'].linear.bias, true_coefs)


# plt.plot(np.arange(len(loss_per_iter)), loss_per_iter, "-", alpha=0.5, label="Loss per epoch")
plt.plot(np.arange(len(test_run['loss'] )), test_run['loss'], "-", alpha=0.5, label="Loss per epoch")
#plt.plot(np.arange(len(test_run_minibatch['valid_loss_per_batch'])), test_run_minibatch['valid_loss_per_batch'], "-", alpha=0.5, label="Validation Loss per epoch")
#    #plt.plot(np.arange(len(loss_per_iter), step=4) + 3, loss_per_batch, ".-", label="Loss per mini-batch")
plt.xlabel("Number of epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# tensor(0.9474, grad_fn=<MaxBackward1>)
# tensor(0.0587, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[-0.4493,  0.1540, -0.3879]], requires_grad=True)
# epoch: 1, loss = 0.7545
# tensor(0.7545)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9233, grad_fn=<MaxBackward1>)
# tensor(0.0975, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[-0.0929,  0.3302, -0.4685]], requires_grad=True)
# epoch: 2, loss = 0.6086
# tensor(0.6086)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9716, grad_fn=<MaxBackward1>)
# tensor(0.0503, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.1816,  0.4649, -0.5292]], requires_grad=True)
# epoch: 3, loss = 0.5221
# tensor(0.5221)
# tensor(-5.9605e-08, grad_fn=<SubBackward0>)
# tensor(0.9875, grad_fn=<MaxBackward1>)
# tensor(0.0221, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.3939,  0.5722, -0.5799]], requires_grad=True)
# epoch: 4, loss = 0.4686
# tensor(0.4686)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9937, grad_fn=<MaxBackward1>)
# tensor(0.0111, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.5629,  0.6615, -0.6253]], requires_grad=True)
# epoch: 5, loss = 0.4332
# tensor(0.4332)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9968, grad_fn=<MaxBackward1>)
# tensor(0.0060, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.7019,  0.7386, -0.6674]], requires_grad=True)
# epoch: 6, loss = 0.4081
# tensor(0.4081)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9984, grad_fn=<MaxBackward1>)
# tensor(0.0034, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.8190,  0.8067, -0.7069]], requires_grad=True)
# epoch: 7, loss = 0.3894
# tensor(0.3894)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9991, grad_fn=<MaxBackward1>)
# tensor(0.0021, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 0.9200,  0.8679, -0.7442]], requires_grad=True)
# epoch: 8, loss = 0.3749
# tensor(0.3749)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9995, grad_fn=<MaxBackward1>)
# tensor(0.0013, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.0084,  0.9237, -0.7796]], requires_grad=True)
# epoch: 9, loss = 0.3633
# tensor(0.3633)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9997, grad_fn=<MaxBackward1>)
# tensor(0.0009, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.0870,  0.9748, -0.8132]], requires_grad=True)
# epoch: 10, loss = 0.3538
# tensor(0.3538)
# tensor(-2.9802e-08, grad_fn=<SubBackward0>)
# tensor(0.9998, grad_fn=<MaxBackward1>)
# tensor(0.0006, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.1577,  1.0222, -0.8452]], requires_grad=True)
# epoch: 11, loss = 0.3459
# tensor(0.3459)
# tensor(2.9802e-08, grad_fn=<SubBackward0>)
# tensor(0.9999, grad_fn=<MaxBackward1>)
# tensor(0.0004, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.2218,  1.0662, -0.8757]], requires_grad=True)
# epoch: 12, loss = 0.3392
# tensor(0.3392)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9999, grad_fn=<MaxBackward1>)
# tensor(0.0003, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.2805,  1.1075, -0.9048]], requires_grad=True)
# epoch: 13, loss = 0.3334
# tensor(0.3334)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9999, grad_fn=<MaxBackward1>)
# tensor(0.0002, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.3345,  1.1462, -0.9326]], requires_grad=True)
# epoch: 14, loss = 0.3284
# tensor(0.3284)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(0.9999, grad_fn=<MaxBackward1>)
# tensor(0.0002, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.3846,  1.1826, -0.9592]], requires_grad=True)
# epoch: 15, loss = 0.3240
# tensor(0.3240)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(0.0001, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.4312,  1.2171, -0.9846]], requires_grad=True)
# epoch: 16, loss = 0.3201
# tensor(0.3201)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(0.0001, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.4749,  1.2498, -1.0089]], requires_grad=True)
# epoch: 17, loss = 0.3166
# tensor(0.3166)
# tensor(-5.9605e-08, grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(8.1934e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.5159,  1.2809, -1.0322]], requires_grad=True)
# epoch: 18, loss = 0.3135
# tensor(0.3135)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(6.5489e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.5545,  1.3105, -1.0546]], requires_grad=True)
# epoch: 19, loss = 0.3107
# tensor(0.3107)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.2920e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.5910,  1.3387, -1.0761]], requires_grad=True)
# epoch: 20, loss = 0.3082
# tensor(0.3082)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(4.3190e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.6257,  1.3656, -1.0968]], requires_grad=True)
# epoch: 21, loss = 0.3059
# tensor(0.3059)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(3.5572e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.6586,  1.3914, -1.1167]], requires_grad=True)
# epoch: 22, loss = 0.3038
# tensor(0.3038)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.9545e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.6900,  1.4162, -1.1358]], requires_grad=True)
# epoch: 23, loss = 0.3018
# tensor(0.3018)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.4729e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.7200,  1.4399, -1.1543]], requires_grad=True)
# epoch: 24, loss = 0.3001
# tensor(0.3001)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.0848e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.7486,  1.4628, -1.1721]], requires_grad=True)
# epoch: 25, loss = 0.2985
# tensor(0.2985)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.7693e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.7760,  1.4847, -1.1893]], requires_grad=True)
# epoch: 26, loss = 0.2970
# tensor(0.2970)
# tensor(2.9802e-08, grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.5110e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.8024,  1.5059, -1.2059]], requires_grad=True)
# epoch: 27, loss = 0.2956
# tensor(0.2956)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.2979e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.8277,  1.5263, -1.2219]], requires_grad=True)
# epoch: 28, loss = 0.2943
# tensor(0.2943)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.1209e-05, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.8520,  1.5460, -1.2375]], requires_grad=True)
# epoch: 29, loss = 0.2931
# tensor(0.2931)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(9.7302e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.8755,  1.5650, -1.2525]], requires_grad=True)
# epoch: 30, loss = 0.2920
# tensor(0.2920)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(8.4871e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.8981,  1.5834, -1.2670]], requires_grad=True)
# epoch: 31, loss = 0.2909
# tensor(0.2909)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(7.4365e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.9200,  1.6012, -1.2811]], requires_grad=True)
# epoch: 32, loss = 0.2899
# tensor(0.2899)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(6.5438e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.9411,  1.6184, -1.2948]], requires_grad=True)
# epoch: 33, loss = 0.2890
# tensor(0.2890)
# tensor(2.9802e-08, grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.7816e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.9615,  1.6351, -1.3081]], requires_grad=True)
# epoch: 34, loss = 0.2882
# tensor(0.2882)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.1278e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 1.9812,  1.6513, -1.3209]], requires_grad=True)
# epoch: 35, loss = 0.2874
# tensor(0.2874)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(4.5645e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0004,  1.6670, -1.3334]], requires_grad=True)
# epoch: 36, loss = 0.2866
# tensor(0.2866)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(4.0772e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0189,  1.6822, -1.3456]], requires_grad=True)
# epoch: 37, loss = 0.2859
# tensor(0.2859)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(3.6538e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0369,  1.6970, -1.3574]], requires_grad=True)
# epoch: 38, loss = 0.2852
# tensor(0.2852)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(3.2847e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0544,  1.7114, -1.3689]], requires_grad=True)
# epoch: 39, loss = 0.2846
# tensor(0.2846)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.9617e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0714,  1.7254, -1.3800]], requires_grad=True)
# epoch: 40, loss = 0.2840
# tensor(0.2840)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.6780e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.0879,  1.7390, -1.3909]], requires_grad=True)
# epoch: 41, loss = 0.2834
# tensor(0.2834)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.4282e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1039,  1.7522, -1.4015]], requires_grad=True)
# epoch: 42, loss = 0.2829
# tensor(0.2829)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.2074e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1195,  1.7651, -1.4118]], requires_grad=True)
# epoch: 43, loss = 0.2824
# tensor(0.2824)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(2.0117e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1347,  1.7776, -1.4218]], requires_grad=True)
# epoch: 44, loss = 0.2819
# tensor(0.2819)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.8377e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1495,  1.7899, -1.4316]], requires_grad=True)
# epoch: 45, loss = 0.2814
# tensor(0.2814)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.6826e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1639,  1.8018, -1.4412]], requires_grad=True)
# epoch: 46, loss = 0.2810
# tensor(0.2810)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.5441e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1780,  1.8134, -1.4505]], requires_grad=True)
# epoch: 47, loss = 0.2806
# tensor(0.2806)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.4199e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.1917,  1.8248, -1.4596]], requires_grad=True)
# epoch: 48, loss = 0.2802
# tensor(0.2802)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.3084e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2050,  1.8358, -1.4685]], requires_grad=True)
# epoch: 49, loss = 0.2798
# tensor(0.2798)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.2080e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2181,  1.8466, -1.4771]], requires_grad=True)
# epoch: 50, loss = 0.2794
# tensor(0.2794)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.1174e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2308,  1.8572, -1.4856]], requires_grad=True)
# epoch: 51, loss = 0.2791
# tensor(0.2791)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(1.0355e-06, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2432,  1.8675, -1.4938]], requires_grad=True)
# epoch: 52, loss = 0.2788
# tensor(0.2788)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(9.6128e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2553,  1.8776, -1.5019]], requires_grad=True)
# epoch: 53, loss = 0.2785
# tensor(0.2785)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(8.9389e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2672,  1.8874, -1.5098]], requires_grad=True)
# epoch: 54, loss = 0.2782
# tensor(0.2782)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(8.3260e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2788,  1.8970, -1.5175]], requires_grad=True)
# epoch: 55, loss = 0.2779
# tensor(0.2779)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(7.7673e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.2901,  1.9064, -1.5251]], requires_grad=True)
# epoch: 56, loss = 0.2776
# tensor(0.2776)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(7.2571e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3012,  1.9156, -1.5325]], requires_grad=True)
# epoch: 57, loss = 0.2774
# tensor(0.2774)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(6.7906e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3120,  1.9246, -1.5397]], requires_grad=True)
# epoch: 58, loss = 0.2771
# tensor(0.2771)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(6.3631e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3226,  1.9334, -1.5468]], requires_grad=True)
# epoch: 59, loss = 0.2769
# tensor(0.2769)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.9708e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3330,  1.9420, -1.5537]], requires_grad=True)
# epoch: 60, loss = 0.2766
# tensor(0.2766)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.6102e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3432,  1.9505, -1.5604]], requires_grad=True)
# epoch: 61, loss = 0.2764
# tensor(0.2764)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1.0000, grad_fn=<MaxBackward1>)
# tensor(5.2782e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3531,  1.9587, -1.5671]], requires_grad=True)
# epoch: 62, loss = 0.2762
# tensor(0.2762)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(1., grad_fn=<MaxBackward1>)
# tensor(4.9722e-07, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[ 2.3629,  1.9668, -1.5736]], requires_grad=True)
# epoch: 63, loss = 0.2760
# tensor(0.2760)
# tensor(0., grad_fn=<SubBackward0>)
# tensor(nan, grad_fn=<MaxBackward1>)
# tensor(nan, grad_fn=<MinBackward1>)
# Parameter containing:
# tensor([[nan, nan, nan]], requires_grad=True)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[81], line 4
#       1 # Fit with torch implementation
#       2 #================================#
# ----> 4 test_run = lr_train(df_train, n_epochs=6500, learn_rate=  1.0, save_name_mod = "", loss_fun = 'mnb')
#       5 #test_run = reg_lr_train_legacy(df_train, n_epochs=100, learn_rate=  0.1, save_name_mod = "", loss_fun = 'mnb')
#       7 print(test_run['net'].linear.weight, test_run['net'].linear.bias, true_coefs)
#
# Cell In[73], line 49, in lr_train(train_in, n_epochs, learn_rate, save_name_mod, loss_fun)
#      45 print(net.linear.weight)
#      47 loss=criterion(y_pred, train_y )
# ---> 49 alt_loss = alt_criterion(y_pred.detach().clone(), train_y.detach().clone())
#      50 #alt_loss = alt_criterion(train_y.detach().clone(), train_y.detach().clone())
#      52 loss.backward()
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/loss.py:618, in BCELoss.forward(self, input, target)
#     617 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 618     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/functional.py:3154, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3151     new_size = _infer_size(target.size(), weight.size())
#    3152     weight = weight.expand(new_size)
# -> 3154 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# RuntimeError: all elements of input should be between 0 and 1

# %%
# Fit with torch minibach implementation
#=======================================

#test_run_minibatch = lr_train_minibatch(df_train, n_epochs=30, batch_size = 10000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')
test_run_minibatch = lr_train_minibatch(df_train, n_epochs=60, batch_size = 10000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'mnb')

test_run_minibatch['model'].linear.weight, test_run_minibatch['model'].linear.bias, true_coefs
# Out:
# (Parameter containing:
#  tensor([[ 2.9430,  2.4569, -1.9624]], requires_grad=True),
#  Parameter containing:
#  tensor([0.0092], requires_grad=True),
#  [3, 2.5, -2.0])

# %%
# Plot the loss 
#==============

# plt.plot(np.arange(len(loss_per_iter)), loss_per_iter, "-", alpha=0.5, label="Loss per epoch")
plt.plot(np.arange(len(test_run_minibatch['loss_per_batch'])), test_run_minibatch['loss_per_batch'], "-", alpha=0.5, label="Loss per epoch")
plt.plot(np.arange(len(test_run_minibatch['valid_loss_per_batch'])), test_run_minibatch['valid_loss_per_batch'], "-", alpha=0.5, label="Validation Loss per epoch")
#    #plt.plot(np.arange(len(loss_per_iter), step=4) + 3, loss_per_batch, ".-", label="Loss per mini-batch")
plt.xlabel("Number of epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Compare model predictions
#============================#

p1 = logreg.predict_proba(df_test[ind_var_names])

test_train_dataset_orig = SynthDataset(df_test)

test_x = torch.from_numpy(test_train_dataset_orig.x.to_numpy().astype(np.float32) )

p2 = test_run(test_x).detach().numpy()

p2
# Out:
# array([[0.5763351 ],
#        [0.31676057],
#        [0.9932608 ],
#        ...,
#        [0.99907196],
#        [0.85202235],
#        [0.42675185]], dtype=float32)

# %%
# Plot the comparison
#=======================#

lt.scatter(p1[:, 1], p2)
plt.xlabel("scikitlearn")
plt.ylabel("numerical optimization")
# Out:
# Text(0, 0.5, 'numerical optimization')

# %%
# Plot the comparison between the learned parameters
#====================================================#

param1 = logreg.coef_[0]
param2 = test_run.linear.weight.detach().numpy()[0]

plt.scatter(true_coefs, param1, label = "scikitlearn")
plt.scatter(true_coefs, param2, label = "numerical", alpha=0.5)

plt.legend(loc='lower right')
plt.xlabel("true log odds")
plt.ylabel("model log ods")
# Out:
# Text(0, 0.5, 'model log ods')

# %%
# Decision curve analysis
#=========================#

#thresh = np.linspace(0.0, 1.0, num=100) 
#
#t = df_test['y']
#p = logreg.predict_proba(df_test[ind_var_names])#
#
#nb = net_benefit(t, p[:, 1] , thresholds=thresh)
#
##--------------
#
#t = df_test['y']
#test_train_dataset_orig = SynthDataset(df_test)
#test_x = torch.from_numpy(test_train_dataset_orig.x.to_numpy().astype(np.float32) )
#p = torch_run(test_x ).detach().numpy()
#
#nb = net_benefit(t, p, thresholds=thresh)
#
#mnb = integrate.simpson(nb[1], x=nb[0])
#
##mean_net_benefit(t, p, 100)



#t.shape
#p.shape
# Out:
# {'mnb': 0.38159407909073045,
#  'benefit': array([0.4987    , 0.49511786, 0.49225464, 0.48966719, 0.48697526,
#         0.48440053, 0.4822629 , 0.48007989, 0.47783407, 0.4755    ,
#         0.47298876, 0.47084375, 0.46838103, 0.46614709, 0.46399412,
#         0.46201786, 0.45993855, 0.45748537, 0.45554444, 0.453415  ,
#         0.45128924, 0.44936923, 0.44781429, 0.44585658, 0.443946  ,
#         0.44216014, 0.44015342, 0.438475  , 0.43635282, 0.43446429,
#         0.43273261, 0.43047794, 0.42890075, 0.427375  , 0.42600154,
#         0.42443047, 0.42230714, 0.42075726, 0.41957705, 0.417715  ,
#         0.41559237, 0.41371034, 0.41099211, 0.40994196, 0.4083    ,
#         0.40611667, 0.40383208, 0.40165   , 0.39936471, 0.397629  ,
#         0.39633776, 0.39413437, 0.39222128, 0.3905337 , 0.38864   ,
#         0.3863125 , 0.3843    , 0.38296786, 0.3805561 , 0.378565  ,
#         0.37660385, 0.37467368, 0.37221081, 0.3702    , 0.36797571,
#         0.36500441, 0.3627    , 0.35968281, 0.35700645, 0.354055  ,
#         0.35045172, 0.34598214, 0.34426667, 0.34063846, 0.337348  ,
#         0.33295625, 0.3296913 , 0.32635   , 0.32271429, 0.3193525 ,
#         0.31417895, 0.3098    , 0.30488235, 0.30151562, 0.2964    ,
#         0.28984643, 0.28494231, 0.2782125 , 0.26875   , 0.262605  ,
#         0.25665   , 0.248025  , 0.24505   , 0.232775  , 0.22263   ,
#         0.214375  , 0.2038    , 0.18975   , 0.1645    , 0.00075   ]),
#  'thresholds': array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#         0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#         0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#         0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#         0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#         0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#         0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#         0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#         0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#         0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#         0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#         0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#         0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#         0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
#         0.70707071, 0.71717172, 0.72727273, 0.73737374, 0.74747475,
#         0.75757576, 0.76767677, 0.77777778, 0.78787879, 0.7979798 ,
#         0.80808081, 0.81818182, 0.82828283, 0.83838384, 0.84848485,
#         0.85858586, 0.86868687, 0.87878788, 0.88888889, 0.8989899 ,
#         0.90909091, 0.91919192, 0.92929293, 0.93939394, 0.94949495,
#         0.95959596, 0.96969697, 0.97979798, 0.98989899, 1.        ])}

# %%
# Bootstrap distributions
# ========================= #

n_bootstraps = 300

coefs_skl = []
coefs_torch = []

aucs_skl = []
aucs_torch = []

mnbs_skl = []
mnbs_torch = []

for boot in range(n_bootstraps):
    #print(boot)
    df_boot = df_train.sample(frac=1, replace=True)

    #scikit learn
    #-------------
    # coefs
    logreg.fit(df_boot[ind_var_names], df_boot["y"])
    coefs_skl.append(logreg.coef_)
    #preds
    pred_skl = logreg.predict_proba(df_test[ind_var_names])
    # auc
    auc_skl = roc_auc_score(df_test['y'],pred_skl[:, 1])

    aucs_skl.append(auc_skl)
    # mnb
    mnbs_skl.append(mean_net_benefit(df_test['y'], pred_skl[:, 1], n_thresh=100)['mnb'])

    # torch
    #-------
    # coefs
    torch_run = lr_train(df_boot, n_epochs=1000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')
    coefs_torch.append(torch_run.linear.weight.detach().numpy())
    #preds
    test_train_dataset_orig = SynthDataset(df_test)
    test_x = torch.from_numpy(test_train_dataset_orig.x.to_numpy().astype(np.float32) )
    pred_torch = torch_run(test_x ).detach().numpy()
    #auc
    auc_torch = roc_auc_score(df_test['y'],pred_torch)
    #mnb
    mnbs_torch.append(mean_net_benefit(df_test['y'], pred_torch, n_thresh=100)['mnb'])

    aucs_torch.append(auc_torch)

coefs_skl = np.vstack(coefs_skl)
coefs_torch = np.vstack(coefs_torch)
#rauc = roc_auc_score(y_test, y_pred_probs_positive)
#accuracy = accuracy_score(y_true, y_pred)
#precision = precision_score(y_true, y_pred)
#recall = recall_score(y_true, y_pred)
#f1 = f1_score(y_true, y_pred)

# %%
plt.hist(aucs_skl, **kwargs, label='0', histtype=u'step', density=True)
plt.hist(aucs_torch, **kwargs, label='1', histtype=u'step', density=True)

plt.legend(loc='upper left')
plt.xlabel("auc")
plt.ylabel("count")

plt.show()

# %%
c = 0

plt.hist(coefs_skl[:, c], **kwargs, label='0', histtype=u'step', density=True)
plt.hist(coefs_torch[:, c], **kwargs, label='1',  histtype=u'step', density=True)

plt.legend(loc='lower right')
plt.xlabel("auc")
plt.ylabel("count")

plt.show()

# %%
plt.hist(mnbs_skl, **kwargs, label='0', histtype=u'step', density=True)
plt.hist(mnbs_torch, **kwargs, label='1', histtype=u'step', density=True)

plt.legend(loc='upper left')
plt.xlabel("auc")
plt.ylabel("count")

plt.show()

# %% [markdown]
# ### Test L1 regularization path

# %%
# Create a dataset
#===================#

#make_synth_data(n_features = 10, n_sample = 100000, true_coefs = [3, 2.5, -2.0, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])
#make_synth_data(n_features = 3, n_sample = 100000, true_coefs = [ 3,2,1 ])
n_sample = 10000
df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs = \
    make_synth_data(n_features = 5, n_sample = n_sample, true_coefs = [3, 2.5, -2.0, 1.8, -1.5])# , 1.2, 0.8, 0.5, -0.2,0.1])

# %%
cs = l1_min_c(df_train[ind_var_names], df_train["y"], loss="log") * np.logspace(0, 5, 16)

clf = LogisticRegression(
    penalty="l1",
    solver="liblinear",
    tol=1e-6,
    max_iter=int(1e6),
    warm_start=True,
    intercept_scaling=10000.0,
)
coefs_ = []
for c in cs:
    clf.set_params(C=c)
    clf.fit(df_train[ind_var_names], df_train["y"] )
    coefs_.append(clf.coef_.ravel().copy())

coefs_ = np.array(coefs_)

# %%
plt.plot(np.log10(cs), coefs_, marker="o")
ymin, ymax = plt.ylim()
plt.xlabel("log(C)")
plt.ylabel("Coefficients")
plt.title("Logistic Regression Path")
plt.axis("tight")
plt.show()

# %%
coefs_.shape

np.logspace(10, 0, 16)
np.logspace(0, 10, 16)
# Out:
# array([1.00000000e+00, 4.64158883e+00, 2.15443469e+01, 1.00000000e+02,
#        4.64158883e+02, 2.15443469e+03, 1.00000000e+04, 4.64158883e+04,
#        2.15443469e+05, 1.00000000e+06, 4.64158883e+06, 2.15443469e+07,
#        1.00000000e+08, 4.64158883e+08, 2.15443469e+09, 1.00000000e+10])

# %%
cs = l1_min_c(df_train[ind_var_names], df_train["y"], loss="log") * np.logspace(5, 0, 32)

#cs = cs[0:8]
test_reg_path = {}

start_model = lr_train(df_train, n_epochs=10000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')

for i, inv_lambda_reg in enumerate(cs):
    print(i)
    #fm = reg_lr_train(df_train, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0])
    print("lambda")
    print(1./inv_lambda_reg)
    lda = 1./(inv_lambda_reg)
    lda = lda/n_sample
    #lda = lda/ n_features
    new_model = \
    reg_lr_train(start_model, df_train, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0], lambda_reg=lda )

    test_reg_path[i] = copy.deepcopy(new_model)

    start_model = copy.deepcopy(new_model)


coefs_num = []

for i in test_reg_path.keys():
    coefs_num.append(test_reg_path[i].linear.weight.detach().numpy()[0])

coefs_num = np.vstack(coefs_num)
# Out:
# 0
# lambda
# 0.018205124990253087
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 17
#      14 lda = lda/n_sample
#      15 #lda = lda/ n_features
#      16 new_model = \
# ---> 17 reg_lr_train(start_model, df_train, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0], lambda_reg=lda )
#      19 test_reg_path[i] = copy.deepcopy(new_model)
#      21 start_model = copy.deepcopy(new_model)
#
# Cell In[22], line 66, in reg_lr_train(net, train_in, n_epochs, learn_rate, save_name_mod, loss_fun, regularization_type, weights, lambda_reg)
#      53     return loss
#      54     #optimizer.step()
#      55
#      56     # Zero the parameter gradients
#    (...)
#      62 #warm_start=True,
#      63 #intercept_scaling=10000.0,
# ---> 66 lbfgs = optim.LBFGS(net.parameters(),
#      67                 history_size=100,
#      68                 max_iter=100,
#      69                 line_search_fn="strong_wolfe")
#      71 # A tensor of weights for the weighted L1
#      72 if regularization_type == 'weighted_L1':
#
# AttributeError: 'dict' object has no attribute 'parameters'

# %%
plt.plot(np.log10(cs[:]), coefs_num[:, :], marker="o")
ymin, ymax = plt.ylim()
plt.xlabel("log(C)")
plt.ylabel("Coefficients")
plt.title("Logistic Regression Path")
plt.axis("tight")
plt.ylim(-3.,3.2)
plt.show()

# %% [markdown]
# #### Examine the efect of noisey features

# %%
# Create a dataset
#===================#

#make_synth_data(n_features = 10, n_sample = 100000, true_coefs = [3, 2.5, -2.0, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])
#make_synth_data(n_features = 3, n_sample = 100000, true_coefs = [ 3,2,1 ])
n_sample = 10000
df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs = \
    make_synth_data(n_features = 5, n_sample = n_sample, true_coefs = [3, 2.5, -2.0, 1.8, -1.5], noise = [0., 0., 0., 3., 5.])# , 1.2, 0.8, 0.5, -0.2,0.1])

# %%
cs = l1_min_c(df_train[ind_var_names], df_noisy_train["y"], loss="log") * np.logspace(0, 5, 16)

clf = LogisticRegression(
    penalty="l1",
    solver="liblinear",
    tol=1e-6,
    max_iter=int(1e6),
    warm_start=True,
    intercept_scaling=10000.0,
)
coefs_ = []
for c in cs:
    clf.set_params(C=c)
    clf.fit(df_noisy_train[ind_var_names], df_noisy_train["y"] )
    coefs_.append(clf.coef_.ravel().copy())

coefs_ = np.array(coefs_)

# %%
plt.plot(np.log10(cs), coefs_, marker="o")
ymin, ymax = plt.ylim()
plt.xlabel("log(C)")
plt.ylabel("Coefficients")
plt.title("Logistic Regression Path")
plt.axis("tight")
plt.show()

# %%
cs = l1_min_c(df_noisy_train[ind_var_names], df_noisy_train["y"], loss="log") * np.logspace(5, 0, 32)

#cs = cs[0:8]
test_reg_path = {}

start_model = lr_train(df_noisy_train, n_epochs=10000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')

for i, inv_lambda_reg in enumerate(cs):
    print(i)
    #fm = reg_lr_train(df_train, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0])
    print("lambda")
    print(1./inv_lambda_reg)
    lda = 1./(inv_lambda_reg)
    lda = lda/n_sample
    #lda = lda/ n_features
    new_model = \
    reg_lr_train(df_noisy_train, net = start_model, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0], lambda_reg=lda )

    test_reg_path[i] = copy.deepcopy(new_model['net'])

    start_model = copy.deepcopy(new_model['net'])


coefs_num = []

for i in test_reg_path.keys():
    coefs_num.append(test_reg_path[i].linear.weight.detach().numpy()[0])

coefs_num = np.vstack(coefs_num)
# Out:
# 0
# lambda
# 0.01765541439832868
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 17
#      14 lda = lda/n_sample
#      15 #lda = lda/ n_features
#      16 new_model = \
# ---> 17 reg_lr_train(df_noisy_train, net = start_model, n_epochs=1000, learn_rate = 1.0, save_name_mod = "", loss_fun = 'log', regularization_type = 'L1', weights = [1.0, 1.0, 1.0], lambda_reg=lda )
#      19 test_reg_path[i] = copy.deepcopy(new_model['net'])
#      21 start_model = copy.deepcopy(new_model['net'])
#
# NameError: name 'reg_lr_train' is not defined

# %%
plt.plot(np.log10(cs[:]), coefs_num[:, :], marker="o")
ymin, ymax = plt.ylim()
plt.xlabel("log(C)")
plt.ylabel("Coefficients")
plt.title("Logistic Regression Path")
plt.axis("tight")
#plt.ylim(-3.,3.2)
plt.show()

# %% [markdown]
# ## Examine Mean net benefit loss function

# %%
# Create a dataset
#===================#

#make_synth_data(n_features = 10, n_sample = 100000, true_coefs = [3, 2.5, -2.0, 1.8, -1.5, 1.2, 0.8, 0.5, -0.2,0.1])
#make_synth_data(n_features = 3, n_sample = 100000, true_coefs = [ 3,2,1 ])
n_sample = 10000
df_train, df_test, df_noisy_train, df_noisy_test, ind_var_names, n_features, true_coefs = \
    make_synth_data(n_features = 5, n_sample = n_sample, true_coefs = [3, 2.5, -2.0, 1.8, -1.5], noise = [0., 0., 0., 3., 5.])# , 1.2, 0.8, 0.5, -0.2,0.1])

# %%
df_boot = df_train.sample(frac=1, replace=True)

coefs_torch = []
# torch
#-------
# coefs
torch_run = lr_train(df_boot, n_epochs=100, learn_rate=  1.0, save_name_mod = "", loss_fun = 'mnb')
coefs_torch.append(torch_run.linear.weight.detach().numpy())
#preds
test_train_dataset_orig = SynthDataset(df_test)
test_x = torch.from_numpy(test_train_dataset_orig.x.to_numpy().astype(np.float32) )
pred_torch = torch_run(test_x ).detach().numpy()
#auc
#auc_torch = roc_auc_score(df_test['y'],pred_torch)
##mnb
#mnbs_torch.append(mean_net_benefit(df_test['y'], pred_torch, n_thresh=100)['mnb'])
#
#aucs_torch.append(auc_torch)

coefs_torch
# Out:
# [array([[nan, nan, nan, nan, nan]], dtype=float32)]

# %%
# Bootstrap distributions
# ========================= #

n_bootstraps = 300

coefs_skl = []
coefs_torch = []

aucs_skl = []
aucs_torch = []

mnbs_skl = []
mnbs_torch = []

for boot in range(n_bootstraps):
    #print(boot)
    df_boot = df_train.sample(frac=1, replace=True)

    #scikit learn
    #-------------
    # coefs
    logreg.fit(df_boot[ind_var_names], df_boot["y"])
    coefs_skl.append(logreg.coef_)
    #preds
    pred_skl = logreg.predict_proba(df_test[ind_var_names])
    # auc
    auc_skl = roc_auc_score(df_test['y'],pred_skl[:, 1])

    aucs_skl.append(auc_skl)
    # mnb
    mnbs_skl.append(mean_net_benefit(df_test['y'], pred_skl[:, 1], n_thresh=100)['mnb'])

    # torch
    #-------
    # coefs
    torch_run = lr_train(df_boot, n_epochs=1000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')
    coefs_torch.append(torch_run.linear.weight.detach().numpy())
    #preds
    test_train_dataset_orig = SynthDataset(df_test)
    test_x = torch.from_numpy(test_train_dataset_orig.x.to_numpy().astype(np.float32) )
    pred_torch = torch_run(test_x ).detach().numpy()
    #auc
    auc_torch = roc_auc_score(df_test['y'],pred_torch)
    #mnb
    mnbs_torch.append(mean_net_benefit(df_test['y'], pred_torch, n_thresh=100)['mnb'])

    aucs_torch.append(auc_torch)

coefs_skl = np.vstack(coefs_skl)
coefs_torch = np.vstack(coefs_torch)
#rauc = roc_auc_score(y_test, y_pred_probs_positive)
#accuracy = accuracy_score(y_true, y_pred)
#precision = precision_score(y_true, y_pred)
#recall = recall_score(y_true, y_pred)
#f1 = f1_score(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 36
#      31 mnbs_skl.append(mean_net_benefit(df_test['y'], pred_skl[:, 1], n_thresh=100)['mnb'])
#      33 # torch
#      34 #-------
#      35 # coefs
# ---> 36 torch_run = lr_train(df_boot, n_epochs=1000, learn_rate=  1.0, save_name_mod = "", loss_fun = 'log')
#      37 coefs_torch.append(torch_run.linear.weight.detach().numpy())
#      38 #preds
#
# Cell In[7], line 39, in lr_train(train_in, n_epochs, learn_rate, save_name_mod, loss_fun)
#      35 for epoch in range(n_epochs):
#      37     y_pred = net(train_x )
# ---> 39     loss=criterion(y_pred, train_y )
#      41     loss.backward()
#      42     optimizer.step()
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/modules/loss.py:618, in BCELoss.forward(self, input, target)
#     617 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 618     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#
# File ~/.conda/envs/pytorch/lib/python3.12/site-packages/torch/nn/functional.py:3154, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3151     new_size = _infer_size(target.size(), weight.size())
#    3152     weight = weight.expand(new_size)
# -> 3154 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Examine DC regularization path
